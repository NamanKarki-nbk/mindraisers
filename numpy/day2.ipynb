# %%
import numpy as np

# %%
arr1 = np.random.rand(5)
print(arr1)
# Out:
# [0.92782043 0.12314495 0.45909732 0.73447404 0.62171131]

# %%
#fancy indexing
print(arr1[[0,2,4]])
# Out:
# [0.92782043 0.45909732 0.62171131]

# %% [markdown]
# TASK: Extract the last 3 elements from the array

# %%
print(arr1[-3:])
# Out:
# [0.45909732 0.73447404 0.62171131]
