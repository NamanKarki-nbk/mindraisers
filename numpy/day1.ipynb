# %% [markdown]
# numpy

# %%
import numpy as np

# %%
arr1 = np.ones(5)
print(arr1)
# Out:
# [1. 1. 1. 1. 1.]

# %%
arr2 = np.zeros(5)
print(arr2)
# Out:
# [0. 0. 0. 0. 0.]

# %%
arr3 = np.arange(1.5,10.5,2)
print(arr3)
# Out:
# [1.5 3.5 5.5 7.5 9.5]

# %%
arr4 = np.linspace(0,1,5)
print(arr4)
# Out:
# [0.   0.25 0.5  0.75 1.  ]
